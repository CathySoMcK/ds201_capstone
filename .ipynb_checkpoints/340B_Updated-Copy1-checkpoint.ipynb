# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import datetime as dt

import pandas as pd
from pandas import ExcelWriter
from pandas import ExcelFile
from pandas.core import datetools

from sklearn.preprocessing import LabelEncoder

import numpy as np

import matplotlib.pyplot as plt

from sklearn import tree
from sklearn.metrics import accuracy_score
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import train_test_split
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression

# %%
# df_raw = pd.read_excel('c:/users/elkzze1/OneDrive - McKesson Corporation/training/ds201_capstone/data/HealthMart_Performance_Data_clean.xlsx', sheet_name='Health_Mart_Store_Progam_List_c')
df_raw = pd.read_excel('c:/users/elkzze1/OneDrive - McKesson Corporation/training/ds201_capstone/data/HM_Master_Data_Analytics_Clean.xlsx', sheet_name='Health_Mart_Store_Progam_List_c')
# data_path = 'c:/users/elkzze1/work/ds201_capstone_data/HM_Master_Data_Analytics_Clean.xlsx' 
# df_raw = pd.read_excel('C:/Users/ekvtjdx/MacroHelix/data/HM_Master_Data_Analytics_Clean.xlsx', sheet_name='Health_Mart_Store_Progam_List_c', index_col=0)
df_raw.head()
# Out:
#    Account  Nabp_Ncpdp     Npi_Num    Dea_Num    Target  \
# 0    10491     3800047  1205901485  AM1635474   10491.0
# 1    17475     3802421  1912059569  AH1621336   17475.0
# 2    19901     3804425  1114456563  AK1605887   19901.0
# 3   309745     3804324  1437294808  FS5689964  309745.0
# 4   652229     3844366  1275808743  FJ3131290  652229.0
#
#                   Store_Name    Address-Delivery City-Delivery  ST    Zip  \
# 0            POSTAL PHARMACY    47809 HIGHWAY 58      OAKRIDGE  OR  97463
# 1              HOWARDS DRUGS  101 NORTH F STREET      LAKEVIEW  OR  97630
# 2       HARVARD AVENUE DRUGS    1175 HARVARD AVE      ROSEBURG  OR  97471
# 3         REEDSPORT PHARMACY        1409 HWY 101     REEDSPORT  OR  97467
# 4  PHILOMATH FAMILY PHARMACY    1640 MAIN STREET     PHILOMATH  OR  97370
#
#        ...      Profitability Annual_Dispense_Fee_Total Macro_PID  \
# 0      ...                NaN                       NaN       NaN
# 1      ...                NaN                       NaN       NaN
# 2      ...                NaN                       NaN       NaN
# 3      ...                NaN                       NaN       NaN
# 4      ...                NaN                       NaN       NaN
#
#   Script_Count  Capture_Rate Specialty_Spend Specialty_Product_Purchases  \
# 0          NaN           NaN             NaN                         NaN
# 1          NaN           NaN             NaN                         NaN
# 2          NaN           NaN             NaN                         NaN
# 3          NaN           NaN             NaN                         NaN
# 4          NaN           NaN             NaN                         NaN
#
#   Generic Brand Generic_Ratio
# 0     NaN   NaN           NaN
# 1     NaN   NaN           NaN
# 2     NaN   NaN           NaN
# 3     NaN   NaN           NaN
# 4     NaN   NaN           NaN
#
# [5 rows x 86 columns]

# %%
df_raw.columns
# Out:
# Index(['Nabp_Ncpdp', 'Npi_Num', 'Dea_Num', 'Target', 'Store_Name',
#        'Address-Delivery', 'City-Delivery', 'ST', 'Zip', 'Owner_Mgr_Full_Name',
#        'Owner_Email', 'Phone_Number', 'Hm_Start_Dt', 'Channel_Type_Cd',
#        'Cust_Type_Desc', 'Bus_Type_Desc', 'Region', 'DC_Name', 'PSAO_Expanded',
#        'Buying_Group', 'Chain_Name', 'Sub_Group_Name', 'Region_Name',
#        'Region_Director', 'Pharm_D', 'Vpgm_Name', 'Vps_Name', 'Dsm_Name',
#        'RSM_Name', 'Salesperson', 'Salesperson_Group', 'AH_Program',
#        'Auto_Ship_Ind', 'DLC_Program', 'FEM_Program', 'HM_Circular_Program',
#        'Internal_Decor', 'Interior_Decor_Signage_Available_Funds',
#        'LMS_Enrolled', 'LMS_Available_Matching_Funds',
#        'LMS_Used_Funds_Most_Recent_3_Months',
#        'LMS_Used_Funds_Previous_3_Months', 'Open_Smart',
#        'MRA_Program_Type_-_Active_AH', 'Msa_Dma', 'OTC_Front-end_Size',
#        'PIP_Program', 'Pog_Code_Name', 'KYN_Training', 'PQS_Enrolled',
#        'PQS_Program', 'Last_EQuIPP_Login', 'PQS_Enrolled_Date', 'SCS_Program',
#        'Signage_Program', 'Spar_Coverage_Ind', 'Specialty_Solutions',
#        'Vaccine_Items', 'Vaccine_Starter', 'Vaccine_Items_Count',
#        'Vaccine_Items_Sls_Amt', 'YPO', 'Tot_Sls_Amt', 'Brand_Rx_Sls_Amt',
#        'Gnrc_Rx_Sls_Amt', 'Os_Gnrc_Rx_Sls_Amt', 'Otc_Sls_Amt', 'HID', 'IS_HID',
#        'Zip_of_HID', 'Zip_Match_Level', '3rd_Party_Vendor',
#        'Hospital_Associated', '340B_Active', '340B_ID', 'Profitability',
#        'Annual_Dispense_Fee_Total', 'Macro_PID', 'Script_Count',
#        'Capture_Rate', 'Specialty_Spend', 'Specialty_Product_Purchases',
#        'Generic', 'Brand', 'Generic_Ratio'],
#       dtype='object')

# %%
# unnamed_cols = df_clean.select(lambda col: col.startswith('Unnamed'), axis=1)
# unnamed_cols.columns

# %%
# df_raw = df_raw.drop(['Unnamed: 86', 'Unnamed: 87', 'Unnamed: 88', 'Unnamed: 89'], axis=1)

# %%
df_raw.Internal_Decor.unique()
# Out:
# array(['X', nan], dtype=object)

# %%
df_clean = df_raw

# %%
# def fill_in_missing_dates(df, date_col_name = 'date',date_order = 'asc', fill_value = 0, days_back = 30):

#     df.set_index(date_col_name,drop=True,inplace=True)
#     df.index = pd.DatetimeIndex(df.index)
#     d = datetime.now().date()
#     d2 = d - timedelta(days = days_back)
#     idx = pd.date_range(d2, d, freq = "D")
#     df = df.reindex(idx,fill_value=fill_value)
#     df[date_col_name] = pd.DatetimeIndex(df.index)

#     return df

# %%
# if you want to operate on multiple columns, put them in a list like so:
dollar_cols = ['Interior_Decor_Signage_Available_Funds', 'LMS_Available_Matching_Funds', 'Tot_Sls_Amt', 'Brand_Rx_Sls_Amt', 
               'Gnrc_Rx_Sls_Amt','Os_Gnrc_Rx_Sls_Amt','Otc_Sls_Amt', 'LMS_Enrolled', 'LMS_Available_Matching_Funds', 
               'Vaccine_Items_Sls_Amt']
X_cols = ['Internal_Decor', 'Open_Smart', 'PIP_Program', 'PQS_Program', 'SCS_Program', 'Specialty_Solutions', 'Vaccine_Items',
          'Vaccine_Starter', 'YPO']
y_n_cols = ['340B_Active', 'LMS_Enrolled', 'LMS_Used_Funds_Most_Recent_3_Months', 'LMS_Used_Funds_Previous_3_Months']
yes_cols = ['Auto_Ship_Ind', 'Spar_Coverage_Ind']
empt_num_cols = ['Profitability', 'Annual_Dispense_Fee_Total', 'Script_Count', 'Macro_PID', 'Capture_Rate', 'Specialty_Spend',
                'Specialty_Product_Purchases', 'Generic', 'Brand', 'Generic_Ratio', 'Vaccine_Items_Count']
date_cols = ['Hm_Start_Dt','KYN_Training', 'Last_EQuIPP_Login', 'PQS_Enrolled_Date'] 
df_clean[X_cols] = df_clean[X_cols].applymap(lambda x: 1 if x == 'X' else 0)
df_clean[y_n_cols] = df_clean[y_n_cols].applymap(lambda x: 1 if x == 'Y' else 0)
df_clean[yes_cols] = df_clean[yes_cols].applymap(lambda x: 1 if x == 'Yes' else 0)
df_clean['3rd_Party_Vendor'] = df_clean['3rd_Party_Vendor'].apply(lambda x: 'UNK' if pd.isnull(x) else x).astype(str)
df_clean['Hospital_Associated'] = df_clean['Hospital_Associated'].apply(lambda x: 'UNK' if pd.isnull(x) else x).astype(str)
df_clean['IS_HID'] = df_clean['HID'].apply(lambda x: 0 if pd.isnull(x) else 1)
df_clean[empt_num_cols] = df_clean[empt_num_cols].applymap(lambda x: 0 if pd.isnull(x) else x)
df_clean['DLC_Program'] = df_clean['DLC_Program'].apply(lambda x: 'DLC_Program' if x == 'X' else ('Unknown' if pd.isnull(x) else x))
df_clean['FEM_Program'] = df_clean['FEM_Program'].apply(lambda x: 'FEM_Program' if x == 'X' else ('Unknown' if pd.isnull(x) else x))
df_clean['HM_Circular_Program'] = df_clean['HM_Circular_Program'].apply(lambda x: 'HM_Circular_Program' if x == 'X' else ('Unknown' if pd.isnull(x) else x))
df_clean[dollar_cols]=df_clean[dollar_cols].fillna(0)
df_clean[date_cols]=df_clean[date_cols].fillna(pd.Timestamp('19740101'))
df_clean['Target']=df_clean['Target'].fillna(0)

# %%
# df_clean['Capture_Rate'].unique
# df_clean['Capture_Rate'].value_counts()
# df_clean['DLC Program'].isnull().values.any()
# df_raw['3rd Party Vendor'] = df_raw['3rd Party Vendor'].astype(str)
# tmp = df_raw['3rd Party Vendor'].fillna(''); isEmpty = tmp==''
# tmp

# %%
# df_raw['3rd Party Vendor'].dtype
df_clean.head(5)
# Out:
#          Nabp_Ncpdp     Npi_Num    Dea_Num    Target  \
# Account
# 10491       3800047  1205901485  AM1635474   10491.0
# 17475       3802421  1912059569  AH1621336   17475.0
# 19901       3804425  1114456563  AK1605887   19901.0
# 309745      3804324  1437294808  FS5689964  309745.0
# 652229      3844366  1275808743  FJ3131290  652229.0
#
#                         Store_Name    Address-Delivery City-Delivery  ST  \
# Account
# 10491              POSTAL PHARMACY    47809 HIGHWAY 58      OAKRIDGE  OR
# 17475                HOWARDS DRUGS  101 NORTH F STREET      LAKEVIEW  OR
# 19901         HARVARD AVENUE DRUGS    1175 HARVARD AVE      ROSEBURG  OR
# 309745          REEDSPORT PHARMACY        1409 HWY 101     REEDSPORT  OR
# 652229   PHILOMATH FAMILY PHARMACY    1640 MAIN STREET     PHILOMATH  OR
#
#            Zip Owner_Mgr_Full_Name      ...      Profitability  \
# Account                                 ...
# 10491    97463        Laurie Patty      ...                0.0
# 17475    97630         Jeff Howard      ...                0.0
# 19901    97471        Philip Kaser      ...                0.0
# 309745   97467  JAMAICA STANDIFORD      ...                0.0
# 652229   97370           SETH PHAN      ...                0.0
#
#         Annual_Dispense_Fee_Total Macro_PID  Script_Count Capture_Rate  \
# Account
# 10491                         0.0       0.0           0.0          0.0
# 17475                         0.0       0.0           0.0          0.0
# 19901                         0.0       0.0           0.0          0.0
# 309745                        0.0       0.0           0.0          0.0
# 652229                        0.0       0.0           0.0          0.0
#
#         Specialty_Spend Specialty_Product_Purchases Generic Brand  \
# Account
# 10491               0.0                         0.0     0.0   0.0
# 17475               0.0                         0.0     0.0   0.0
# 19901               0.0                         0.0     0.0   0.0
# 309745              0.0                         0.0     0.0   0.0
# 652229              0.0                         0.0     0.0   0.0
#
#         Generic_Ratio
# Account
# 10491             0.0
# 17475             0.0
# 19901             0.0
# 309745            0.0
# 652229            0.0
#
# [5 rows x 85 columns]

# %%
# df_clean = df_raw[['Account','Store Name','AddressDelivery','CityDelivery','ST','Zip','Region','DC Name','PSAO Expanded',
#                    'Buying Group','AH Program','Auto Ship Ind','DLC Program','FEM Program','HM Circular Program',
#                    'Internal Decor','Interior Decor / Signage Available Funds','LMS Enrolled','LMS Available Matching Funds',
#                    'LMS Used Funds Most Recent 3 Months','LMS Used Funds Previous 3 Months','Open Smart',
#                    'MRA Program Type  Active AH','OTC Frontend Size','PIP Program','Pog Code Name', 'PQS Enrolled',
#                    'Last EQuIPP Login','SCS Program','Specialty Solutions','Vaccine Items','Vaccine Starter',
#                    'Vaccine Items Count','Vaccine Items Sls Amt','YPO','Tot Sls Amt','Brand Rx Sls Amt','Gnrc Rx Sls Amt',
#                    'Os Gnrc Rx Sls Amt','Otc Sls Amt','3rd Party Vendor','Hospital Associated','340B Active']]
# df_clean.head()

# %%
# df_clean['LMS_Enrolled'].value_counts()
df_clean['LMS_Enrolled'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
# df_clean['Interior Decor / Signage Available Funds'].value_counts

# %%
df_clean.columns
# Out:
# Index(['Nabp_Ncpdp', 'Npi_Num', 'Dea_Num', 'Target', 'Store_Name',
#        'Address-Delivery', 'City-Delivery', 'ST', 'Zip', 'Owner_Mgr_Full_Name',
#        'Owner_Email', 'Phone_Number', 'Hm_Start_Dt', 'Channel_Type_Cd',
#        'Cust_Type_Desc', 'Bus_Type_Desc', 'Region', 'DC_Name', 'PSAO_Expanded',
#        'Buying_Group', 'Chain_Name', 'Sub_Group_Name', 'Region_Name',
#        'Region_Director', 'Pharm_D', 'Vpgm_Name', 'Vps_Name', 'Dsm_Name',
#        'RSM_Name', 'Salesperson', 'Salesperson_Group', 'AH_Program',
#        'Auto_Ship_Ind', 'DLC_Program', 'FEM_Program', 'HM_Circular_Program',
#        'Internal_Decor', 'Interior_Decor_Signage_Available_Funds',
#        'LMS_Enrolled', 'LMS_Available_Matching_Funds',
#        'LMS_Used_Funds_Most_Recent_3_Months',
#        'LMS_Used_Funds_Previous_3_Months', 'Open_Smart',
#        'MRA_Program_Type_-_Active_AH', 'Msa_Dma', 'OTC_Front-end_Size',
#        'PIP_Program', 'Pog_Code_Name', 'KYN_Training', 'PQS_Enrolled',
#        'PQS_Program', 'Last_EQuIPP_Login', 'PQS_Enrolled_Date', 'SCS_Program',
#        'Signage_Program', 'Spar_Coverage_Ind', 'Specialty_Solutions',
#        'Vaccine_Items', 'Vaccine_Starter', 'Vaccine_Items_Count',
#        'Vaccine_Items_Sls_Amt', 'YPO', 'Tot_Sls_Amt', 'Brand_Rx_Sls_Amt',
#        'Gnrc_Rx_Sls_Amt', 'Os_Gnrc_Rx_Sls_Amt', 'Otc_Sls_Amt', 'HID', 'IS_HID',
#        'Zip_of_HID', 'Zip_Match_Level', '3rd_Party_Vendor',
#        'Hospital_Associated', '340B_Active', '340B_ID', 'Profitability',
#        'Annual_Dispense_Fee_Total', 'Macro_PID', 'Script_Count',
#        'Capture_Rate', 'Specialty_Spend', 'Specialty_Product_Purchases',
#        'Generic', 'Brand', 'Generic_Ratio'],
#       dtype='object')

# %%
# to drop from df_clean
drop_cols = ['Nabp_Ncpdp','Npi_Num','Dea_Num','Target','Store_Name','Address-Delivery','City-Delivery','Cust_Type_Desc', 
             'Owner_Mgr_Full_Name', 'Owner_Email', 'Phone_Number','Sub_Group_Name','Region_Director','Pharm_D','Vpgm_Name',
             'Vps_Name','Dsm_Name', 'RSM_Name','Salesperson_Group', 'Zip_of_HID','HID','Zip_Match_Level','340B_ID']
df_clean = df_clean.drop(drop_cols, axis=1)

# %%
# df_clean = df_clean[['ST','Zip','Hm_Start_Dt','Channel_Type_Cd','Cust_Type_Desc','Bus_Type_Desc','Region','DC_Name',
#                      'PSAO_Expanded','Buying_Group','Chain_Name','Region_Name','Salesperson','AH_Program','Auto_Ship_Ind',
#                      'DLC_Program','FEM_Program','HM_Circular_Program','Internal_Decor','Interior_Decor_Signage_Available_Funds',
#                      'LMS_Enrolled','LMS_Available_Matching_Funds','LMS_Used_Funds_Most_Recent_3_Months',
#                      'LMS_Used_Funds_Previous_3_Months','Open_Smart','MRA_Program_Type_-_Active_AH','Msa_Dma',
#                      'OTC_Frontend_Size','PIP_Program','Pog_Code_Name','KYN_Training','PQS_Enrolled','PQS_Program',
#                      'Last_EQuIPP_Login','PQS_Enrolled_Date','SCS_Program','Signage_Program','Spar_Coverage_Ind',
#                      'Specialty_Solutions','Vaccine_Items','Vaccine_Starter','Vaccine_Items_Count','Vaccine_Items_Sls_Amt','YPO',
#                      'Tot_Sls_Amt','Brand_Rx_Sls_Amt','Gnrc_Rx_Sls_Amt','Os_Gnrc_Rx_Sls_Amt','Otc_Sls_Amt','HID',
#                      '3rd_Party_Vendor','Hospital_Associated','340B_Active','Profitability','Annual_Dispense_Fee_Total',
#                      'Macro_PID','Script_Count','Capture_Rate','Specialty_Spend','Specialty_Product_Purchases','Generic',
#                      'Brand','Generic_Ratio']]

# %%
df_clean.columns
# Out:
# Index(['ST', 'Zip', 'Hm_Start_Dt', 'Channel_Type_Cd', 'Bus_Type_Desc',
#        'Region', 'DC_Name', 'PSAO_Expanded', 'Buying_Group', 'Chain_Name',
#        'Region_Name', 'Salesperson', 'AH_Program', 'Auto_Ship_Ind',
#        'DLC_Program', 'FEM_Program', 'HM_Circular_Program', 'Internal_Decor',
#        'Interior_Decor_Signage_Available_Funds', 'LMS_Enrolled',
#        'LMS_Available_Matching_Funds', 'LMS_Used_Funds_Most_Recent_3_Months',
#        'LMS_Used_Funds_Previous_3_Months', 'Open_Smart',
#        'MRA_Program_Type_-_Active_AH', 'Msa_Dma', 'OTC_Front-end_Size',
#        'PIP_Program', 'Pog_Code_Name', 'KYN_Training', 'PQS_Enrolled',
#        'PQS_Program', 'Last_EQuIPP_Login', 'PQS_Enrolled_Date', 'SCS_Program',
#        'Signage_Program', 'Spar_Coverage_Ind', 'Specialty_Solutions',
#        'Vaccine_Items', 'Vaccine_Starter', 'Vaccine_Items_Count',
#        'Vaccine_Items_Sls_Amt', 'YPO', 'Tot_Sls_Amt', 'Brand_Rx_Sls_Amt',
#        'Gnrc_Rx_Sls_Amt', 'Os_Gnrc_Rx_Sls_Amt', 'Otc_Sls_Amt', 'IS_HID',
#        '3rd_Party_Vendor', 'Hospital_Associated', '340B_Active',
#        'Profitability', 'Annual_Dispense_Fee_Total', 'Macro_PID',
#        'Script_Count', 'Capture_Rate', 'Specialty_Spend',
#        'Specialty_Product_Purchases', 'Generic', 'Brand', 'Generic_Ratio'],
#       dtype='object')

# %%
df_clean[date_cols]=df_clean[date_cols].applymap(dt.datetime.toordinal)
# these cat_cols need to have categorized data so we can include them in the analysis
cat_cols = ['DLC_Program', 'FEM_Program', 'HM_Circular_Program', 'PQS_Enrolled', 'ST', 'Pog_Code_Name',
            'DC_Name', 'Bus_Type_Desc', 'Region', 'DC_Name', 'PSAO_Expanded', 'Buying_Group', 'Chain_Name', 'Region_Name', 
            'Salesperson', 'AH_Program', 'OTC_Front-end_Size', 'MRA_Program_Type_-_Active_AH', 'Msa_Dma', 'Signage_Program', 
            '3rd_Party_Vendor', 'Hospital_Associated']
le = LabelEncoder()
# df_clean['ST_encoded'] = le.fit_transform(df_clean['ST'])
# df_clean['DLC_Program_encoded'] = le.fit_transform(df_clean['DLC_Program'])
for lbl in cat_cols:
    new_la = lbl + '_encoded'
    df_clean[new_la] = le.fit_transform(df_clean[lbl].astype(str))
# drop_enc_cols = (['DLC_Program', 'FEM_Program', 'HM_Circular_Program', 'Internal_Decor', 'PQS_Enrolled', 'ST', 'Pog_Code_Name',
#                     'DC_Name', 'Bus_Type_Desc', 'Region', 'PSAO_Expanded', ])
df_clean = df_clean.drop(cat_cols, axis=1)
df_clean.head(5)
# Out:
#    Account    Zip  Hm_Start_Dt  Channel_Type_Cd  Auto_Ship_Ind  \
# 0    10491  97463       732524               30              1
# 1    17475  97630       732687               30              1
# 2    19901  97471       732616               30              0
# 3   309745  97467       735998               30              0
# 4   652229  97370       734702               30              0
#
#    Internal_Decor  Interior_Decor_Signage_Available_Funds  LMS_Enrolled  \
# 0               1                                  1724.0             1
# 1               1                                     0.0             1
# 2               1                                     0.0             1
# 3               0                                  2500.0             1
# 4               1                                     0.0             1
#
#    LMS_Available_Matching_Funds  LMS_Used_Funds_Most_Recent_3_Months  \
# 0                         822.0                                    1
# 1                           0.0                                    1
# 2                           0.0                                    1
# 3                           0.0                                    0
# 4                         340.0                                    1
#
#               ...               Chain_Name_encoded  Region_Name_encoded  \
# 0             ...                               39                   23
# 1             ...                               39                   23
# 2             ...                               39                   23
# 3             ...                               39                   23
# 4             ...                               38                   23
#
#    Salesperson_encoded  AH_Program_encoded  OTC_Front-end_Size_encoded  \
# 0                    1                   4                           1
# 1                    1                   0                           3
# 2                    1                   0                           4
# 3                    1                   0                           1
# 4                    1                   0                           0
#
#    MRA_Program_Type_-_Active_AH_encoded  Msa_Dma_encoded  \
# 0                                     7              183
# 1                                     3              190
# 2                                     2              183
# 3                                     8              183
# 4                                     8              183
#
#    Signage_Program_encoded  3rd_Party_Vendor_encoded  \
# 0                        0                        18
# 1                        0                        18
# 2                        0                        18
# 3                        3                        18
# 4                        0                        18
#
#    Hospital_Associated_encoded
# 0                           15
# 1                           15
# 2                           15
# 3                           15
# 4                           15
#
# [5 rows x 63 columns]

# %%
# label_encoder=LabelEncoder()
# X['DLC Program'] = labelencoder_X.fit_transform(X['DLC Program'])
# df["ModelNumeric"] = df["Model"].astype("category", ordered = True).cat.codes # Thank you B.Turnwald

# %%
# df_clean['Target'].unique()
# df_clean.isnull().head(6)
# df_clean.isnull().values.any()

null_columns=df_clean.columns[df_clean.isnull().any()]
df_clean[null_columns].isnull().sum()
# Out:
# Series([], dtype: float64)

# %%
# print(df_raw.loc[df_raw['340B Active'] == 1])
# df_is = df_clean.loc[df_clean['340B Active'] == 1]
# df_is.head()

# %%
df_clean.head()
# Out:
#            Zip  Hm_Start_Dt  Channel_Type_Cd  Auto_Ship_Ind  Internal_Decor  \
# Account
# 10491    97463       732524               30              1               1
# 17475    97630       732687               30              1               1
# 19901    97471       732616               30              0               1
# 309745   97467       735998               30              0               0
# 652229   97370       734702               30              0               1
#
#          Interior_Decor_Signage_Available_Funds  LMS_Enrolled  \
# Account
# 10491                                    1724.0             1
# 17475                                       0.0             1
# 19901                                       0.0             1
# 309745                                   2500.0             1
# 652229                                      0.0             1
#
#          LMS_Available_Matching_Funds  LMS_Used_Funds_Most_Recent_3_Months  \
# Account
# 10491                           822.0                                    1
# 17475                             0.0                                    1
# 19901                             0.0                                    1
# 309745                            0.0                                    0
# 652229                          340.0                                    1
#
#          LMS_Used_Funds_Previous_3_Months             ...               \
# Account                                               ...
# 10491                                   1             ...
# 17475                                   1             ...
# 19901                                   1             ...
# 309745                                  0             ...
# 652229                                  0             ...
#
#          Chain_Name_encoded  Region_Name_encoded  Salesperson_encoded  \
# Account
# 10491                    39                   23                    1
# 17475                    39                   23                    1
# 19901                    39                   23                    1
# 309745                   39                   23                    1
# 652229                   38                   23                    1
#
#          AH_Program_encoded  OTC_Front-end_Size_encoded  \
# Account
# 10491                     4                           1
# 17475                     0                           3
# 19901                     0                           4
# 309745                    0                           1
# 652229                    0                           0
#
#          MRA_Program_Type_-_Active_AH_encoded  Msa_Dma_encoded  \
# Account
# 10491                                       7              183
# 17475                                       3              190
# 19901                                       2              183
# 309745                                      8              183
# 652229                                      8              183
#
#          Signage_Program_encoded  3rd_Party_Vendor_encoded  \
# Account
# 10491                          0                        18
# 17475                          0                        18
# 19901                          0                        18
# 309745                         3                        18
# 652229                         0                        18
#
#          Hospital_Associated_encoded
# Account
# 10491                             15
# 17475                             15
# 19901                             15
# 309745                            15
# 652229                            15
#
# [5 rows x 62 columns]

# %%
df_clean.columns
# Out:
# Index(['Zip', 'Hm_Start_Dt', 'Channel_Type_Cd', 'Auto_Ship_Ind',
#        'Internal_Decor', 'Interior_Decor_Signage_Available_Funds',
#        'LMS_Enrolled', 'LMS_Available_Matching_Funds',
#        'LMS_Used_Funds_Most_Recent_3_Months',
#        'LMS_Used_Funds_Previous_3_Months', 'Open_Smart', 'PIP_Program',
#        'KYN_Training', 'PQS_Program', 'Last_EQuIPP_Login', 'PQS_Enrolled_Date',
#        'SCS_Program', 'Spar_Coverage_Ind', 'Specialty_Solutions',
#        'Vaccine_Items', 'Vaccine_Starter', 'Vaccine_Items_Count',
#        'Vaccine_Items_Sls_Amt', 'YPO', 'Tot_Sls_Amt', 'Brand_Rx_Sls_Amt',
#        'Gnrc_Rx_Sls_Amt', 'Os_Gnrc_Rx_Sls_Amt', 'Otc_Sls_Amt', 'IS_HID',
#        '340B_Active', 'Profitability', 'Annual_Dispense_Fee_Total',
#        'Macro_PID', 'Script_Count', 'Capture_Rate', 'Specialty_Spend',
#        'Specialty_Product_Purchases', 'Generic', 'Brand', 'Generic_Ratio',
#        'DLC_Program_encoded', 'FEM_Program_encoded',
#        'HM_Circular_Program_encoded', 'PQS_Enrolled_encoded', 'ST_encoded',
#        'Pog_Code_Name_encoded', 'DC_Name_encoded', 'Bus_Type_Desc_encoded',
#        'Region_encoded', 'PSAO_Expanded_encoded', 'Buying_Group_encoded',
#        'Chain_Name_encoded', 'Region_Name_encoded', 'Salesperson_encoded',
#        'AH_Program_encoded', 'OTC_Front-end_Size_encoded',
#        'MRA_Program_Type_-_Active_AH_encoded', 'Msa_Dma_encoded',
#        'Signage_Program_encoded', '3rd_Party_Vendor_encoded',
#        'Hospital_Associated_encoded'],
#       dtype='object')

# %%
# df_clean.loc[:, df_clean.dtypes == object]
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4846 entries, 10491 to 994517
# Data columns (total 62 columns):
# Zip                                       4846 non-null int64
# Hm_Start_Dt                               4846 non-null int64
# Channel_Type_Cd                           4846 non-null int64
# Auto_Ship_Ind                             4846 non-null int64
# Internal_Decor                            4846 non-null int64
# Interior_Decor_Signage_Available_Funds    4846 non-null float64
# LMS_Enrolled                              4846 non-null int64
# LMS_Available_Matching_Funds              4846 non-null float64
# LMS_Used_Funds_Most_Recent_3_Months       4846 non-null int64
# LMS_Used_Funds_Previous_3_Months          4846 non-null int64
# Open_Smart                                4846 non-null int64
# PIP_Program                               4846 non-null int64
# KYN_Training                              4846 non-null int64
# PQS_Program                               4846 non-null int64
# Last_EQuIPP_Login                         4846 non-null int64
# PQS_Enrolled_Date                         4846 non-null int64
# SCS_Program                               4846 non-null int64
# Spar_Coverage_Ind                         4846 non-null int64
# Specialty_Solutions                       4846 non-null int64
# Vaccine_Items                             4846 non-null int64
# Vaccine_Starter                           4846 non-null int64
# Vaccine_Items_Count                       4846 non-null float64
# Vaccine_Items_Sls_Amt                     4846 non-null float64
# YPO                                       4846 non-null int64
# Tot_Sls_Amt                               4846 non-null float64
# Brand_Rx_Sls_Amt                          4846 non-null float64
# Gnrc_Rx_Sls_Amt                           4846 non-null float64
# Os_Gnrc_Rx_Sls_Amt                        4846 non-null float64
# Otc_Sls_Amt                               4846 non-null float64
# IS_HID                                    4846 non-null int64
# 340B_Active                               4846 non-null int64
# Profitability                             4846 non-null float64
# Annual_Dispense_Fee_Total                 4846 non-null float64
# Macro_PID                                 4846 non-null float64
# Script_Count                              4846 non-null float64
# Capture_Rate                              4846 non-null float64
# Specialty_Spend                           4846 non-null float64
# Specialty_Product_Purchases               4846 non-null float64
# Generic                                   4846 non-null float64
# Brand                                     4846 non-null float64
# Generic_Ratio                             4846 non-null float64
# DLC_Program_encoded                       4846 non-null int64
# FEM_Program_encoded                       4846 non-null int64
# HM_Circular_Program_encoded               4846 non-null int64
# PQS_Enrolled_encoded                      4846 non-null int64
# ST_encoded                                4846 non-null int64
# Pog_Code_Name_encoded                     4846 non-null int64
# DC_Name_encoded                           4846 non-null int64
# Bus_Type_Desc_encoded                     4846 non-null int64
# Region_encoded                            4846 non-null int64
# PSAO_Expanded_encoded                     4846 non-null int64
# Buying_Group_encoded                      4846 non-null int64
# Chain_Name_encoded                        4846 non-null int64
# Region_Name_encoded                       4846 non-null int64
# Salesperson_encoded                       4846 non-null int64
# AH_Program_encoded                        4846 non-null int64
# OTC_Front-end_Size_encoded                4846 non-null int64
# MRA_Program_Type_-_Active_AH_encoded      4846 non-null int64
# Msa_Dma_encoded                           4846 non-null int64
# Signage_Program_encoded                   4846 non-null int64
# 3rd_Party_Vendor_encoded                  4846 non-null int64
# Hospital_Associated_encoded               4846 non-null int64
# dtypes: float64(19), int64(43)
# memory usage: 2.3 MB

# %%
df_clean['IS_HID'].unique()
df_clean['IS_HID'].value_counts()
# Out:
# 0    4669
# 1     177
# Name: IS_HID, dtype: int64

# %%
X = df_clean[[
       'Zip', 'Hm_Start_Dt', 'Channel_Type_Cd', 'Auto_Ship_Ind',
       'Interior_Decor_Signage_Available_Funds', 'LMS_Enrolled',
       'LMS_Available_Matching_Funds', 'LMS_Used_Funds_Most_Recent_3_Months',
       'LMS_Used_Funds_Previous_3_Months', 'Open_Smart', 'PIP_Program',
       'KYN_Training', 'PQS_Program', 'Last_EQuIPP_Login', 'PQS_Enrolled_Date',
       'SCS_Program', 'Spar_Coverage_Ind', 'Specialty_Solutions',
       'Vaccine_Items', 'Vaccine_Starter', 'Vaccine_Items_Count',
       'Vaccine_Items_Sls_Amt', 'YPO', 'Tot_Sls_Amt', 'Brand_Rx_Sls_Amt',
       'Gnrc_Rx_Sls_Amt', 'Os_Gnrc_Rx_Sls_Amt', 'Otc_Sls_Amt', 
       '340B_Active', 'Profitability', 'Annual_Dispense_Fee_Total',
       'Macro_PID', 'Script_Count', 'Capture_Rate', 'Specialty_Spend',
       'Specialty_Product_Purchases', 'Generic', 'Brand', 'Generic_Ratio',
       'DLC_Program_encoded', 'FEM_Program_encoded',
       'HM_Circular_Program_encoded', 'Internal_Decor',
       'PQS_Enrolled_encoded', 'ST_encoded', 'Pog_Code_Name_encoded',
       'DC_Name_encoded', 'Bus_Type_Desc_encoded', 'Region_encoded',
       'PSAO_Expanded_encoded', 'Buying_Group_encoded', 'Chain_Name_encoded',
       'Region_Name_encoded', 'Salesperson_encoded', 'AH_Program_encoded',
       'OTC_Front-end_Size_encoded', 'MRA_Program_Type_-_Active_AH_encoded',
       'Msa_Dma_encoded', 'Signage_Program_encoded',
       '3rd_Party_Vendor_encoded', 'Hospital_Associated_encoded']]

y = df_clean['IS_HID'] 
# X = sm.add_constant(X)
# lr = sm.OLS(y, X)
# lr = lr.fit()
# lr.summary()  
logit = sm.Logit(y, X)
result = logit.fit(method='bfgs') 
result.summary()
# model = LogisticRegression(fit_intercept=False)
# mdl = model.fit(X,y)
# model.coef_
# Out:
# C:\Users\elkzze1\anaconda\anaconda3\envs\py3\lib\site-packages\statsmodels\discrete\discrete_model.py:1214: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# C:\Users\elkzze1\anaconda\anaconda3\envs\py3\lib\site-packages\statsmodels\discrete\discrete_model.py:1264: RuntimeWarning: divide by zero encountered in log
#   return np.sum(np.log(self.cdf(q*np.dot(X,params))))
# C:\Users\elkzze1\anaconda\anaconda3\envs\py3\lib\site-packages\statsmodels\discrete\discrete_model.py:1214: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# C:\Users\elkzze1\anaconda\anaconda3\envs\py3\lib\site-packages\statsmodels\discrete\discrete_model.py:1264: RuntimeWarning: divide by zero encountered in log
#   return np.sum(np.log(self.cdf(q*np.dot(X,params))))
# C:\Users\elkzze1\anaconda\anaconda3\envs\py3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.693147
#          Iterations: 0
#          Function evaluations: 16
#          Gradient evaluations: 4
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                 IS_HID   No. Observations:                 4846
# Model:                          Logit   Df Residuals:                     4785
# Method:                           MLE   Df Model:                           60
# Date:                Sun, 11 Feb 2018   Pseudo R-squ.:                  -3.422
# Time:                        09:31:20   Log-Likelihood:                -3359.0
# converged:                      False   LL-Null:                       -759.55
#                                         LLR p-value:                     1.000
# ==========================================================================================================
#                                              coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------
# Zip                                             0   2.12e-06          0      1.000   -4.16e-06    4.16e-06
# Hm_Start_Dt                                     0   1.62e-05          0      1.000   -3.17e-05    3.17e-05
# Channel_Type_Cd                                 0      0.028          0      1.000      -0.055       0.055
# Auto_Ship_Ind                                   0      0.068          0      1.000      -0.133       0.133
# Interior_Decor_Signage_Available_Funds          0   3.77e-05          0      1.000   -7.38e-05    7.38e-05
# LMS_Enrolled                                    0      0.090          0      1.000      -0.176       0.176
# LMS_Available_Matching_Funds                    0   1.43e-05          0      1.000   -2.81e-05    2.81e-05
# LMS_Used_Funds_Most_Recent_3_Months             0      0.092          0      1.000      -0.180       0.180
# LMS_Used_Funds_Previous_3_Months                0      0.092          0      1.000      -0.181       0.181
# Open_Smart                                      0      0.118          0      1.000      -0.230       0.230
# PIP_Program                                     0      0.079          0      1.000      -0.155       0.155
# KYN_Training                                    0   4.91e-06          0      1.000   -9.63e-06    9.63e-06
# PQS_Program                                     0      0.110          0      1.000      -0.215       0.215
# Last_EQuIPP_Login                               0   5.63e-06          0      1.000    -1.1e-05     1.1e-05
# PQS_Enrolled_Date                               0   1.58e-05          0      1.000    -3.1e-05     3.1e-05
# SCS_Program                                     0      0.078          0      1.000      -0.152       0.152
# Spar_Coverage_Ind                               0      0.079          0      1.000      -0.154       0.154
# Specialty_Solutions                             0      0.165          0      1.000      -0.323       0.323
# Vaccine_Items                                   0      0.083          0      1.000      -0.162       0.162
# Vaccine_Starter                                 0      0.139          0      1.000      -0.272       0.272
# Vaccine_Items_Count                             0      0.026          0      1.000      -0.052       0.052
# Vaccine_Items_Sls_Amt                           0   3.14e-05          0      1.000   -6.16e-05    6.16e-05
# YPO                                             0      0.080          0      1.000      -0.157       0.157
# Tot_Sls_Amt                                     0      0.045          0      1.000      -0.087       0.087
# Brand_Rx_Sls_Amt                                0      0.045          0      1.000      -0.087       0.087
# Gnrc_Rx_Sls_Amt                                 0      0.045          0      1.000      -0.087       0.087
# Os_Gnrc_Rx_Sls_Amt                              0      0.045          0      1.000      -0.087       0.087
# Otc_Sls_Amt                                     0      0.045          0      1.000      -0.087       0.087
# 340B_Active                                     0      0.300          0      1.000      -0.587       0.587
# Profitability                                   0   6.52e-07          0      1.000   -1.28e-06    1.28e-06
# Annual_Dispense_Fee_Total                       0   1.27e-06          0      1.000    -2.5e-06     2.5e-06
# Macro_PID                                       0   3.01e-05          0      1.000    -5.9e-05     5.9e-05
# Script_Count                                    0   6.96e-06          0      1.000   -1.36e-05    1.36e-05
# Capture_Rate                                    0      1.335          0      1.000      -2.617       2.617
# Specialty_Spend                                 0   1.62e-06          0      1.000   -3.17e-06    3.17e-06
# Specialty_Product_Purchases                     0      0.003          0      1.000      -0.006       0.006
# Generic                                         0   8.77e-06          0      1.000   -1.72e-05    1.72e-05
# Brand                                           0   9.81e-05          0      1.000      -0.000       0.000
# Generic_Ratio                                   0      0.479          0      1.000      -0.938       0.938
# DLC_Program_encoded                             0      0.017          0      1.000      -0.033       0.033
# FEM_Program_encoded                             0      0.028          0      1.000      -0.056       0.056
# HM_Circular_Program_encoded                     0      0.072          0      1.000      -0.140       0.140
# Internal_Decor                                  0      0.090          0      1.000      -0.177       0.177
# PQS_Enrolled_encoded                            0      0.266          0      1.000      -0.521       0.521
# ST_encoded                                      0      0.002          0      1.000      -0.004       0.004
# Pog_Code_Name_encoded                           0      0.018          0      1.000      -0.036       0.036
# DC_Name_encoded                                 0      0.004          0      1.000      -0.009       0.009
# Bus_Type_Desc_encoded                           0      0.019          0      1.000      -0.037       0.037
# Region_encoded                                  0      0.036          0      1.000      -0.070       0.070
# PSAO_Expanded_encoded                           0      0.012          0      1.000      -0.023       0.023
# Buying_Group_encoded                            0      0.008          0      1.000      -0.015       0.015
# Chain_Name_encoded                              0      0.004          0      1.000      -0.009       0.009
# Region_Name_encoded                             0      0.005          0      1.000      -0.009       0.009
# Salesperson_encoded                             0      0.001          0      1.000      -0.002       0.002
# AH_Program_encoded                              0      0.041          0      1.000      -0.080       0.080
# OTC_Front-end_Size_encoded                      0      0.020          0      1.000      -0.039       0.039
# MRA_Program_Type_-_Active_AH_encoded            0      0.014          0      1.000      -0.028       0.028
# Msa_Dma_encoded                                 0      0.001          0      1.000      -0.002       0.002
# Signage_Program_encoded                         0      0.031          0      1.000      -0.062       0.062
# 3rd_Party_Vendor_encoded                        0      0.011          0      1.000      -0.021       0.021
# Hospital_Associated_encoded                     0      0.008          0      1.000      -0.016       0.016
# ==========================================================================================================
# """

# %%
X.head(10)
# Out:
#            Zip  Hm_Start_Dt  Channel_Type_Cd  Auto_Ship_Ind  \
# Account
# 10491    97463       732524               30              1
# 17475    97630       732687               30              1
# 19901    97471       732616               30              0
# 309745   97467       735998               30              0
# 652229   97370       734702               30              0
# 121439   49242       735369               30              1
# 9948     43606       734825               30              1
# 13973    48101       735510               30              0
# 18052    48033       735206               30              0
# 18535    43551       734998               30              0
#
#          Interior_Decor_Signage_Available_Funds  LMS_Enrolled  \
# Account
# 10491                                    1724.0             1
# 17475                                       0.0             1
# 19901                                       0.0             1
# 309745                                   2500.0             1
# 652229                                      0.0             1
# 121439                                   2500.0             1
# 9948                                        0.0             1
# 13973                                    2500.0             1
# 18052                                       0.0             1
# 18535                                       0.0             1
#
#          LMS_Available_Matching_Funds  LMS_Used_Funds_Most_Recent_3_Months  \
# Account
# 10491                           822.0                                    1
# 17475                             0.0                                    1
# 19901                             0.0                                    1
# 309745                            0.0                                    0
# 652229                          340.0                                    1
# 121439                         2415.0                                    1
# 9948                           2233.0                                    1
# 13973                          1200.0                                    0
# 18052                          1200.0                                    0
# 18535                          1900.0                                    1
#
#          LMS_Used_Funds_Previous_3_Months  Open_Smart  \
# Account
# 10491                                   1           0
# 17475                                   1           0
# 19901                                   1           0
# 309745                                  0           0
# 652229                                  0           0
# 121439                                  1           0
# 9948                                    1           0
# 13973                                   0           0
# 18052                                   0           0
# 18535                                   1           0
#
#                     ...               Chain_Name_encoded  Region_Name_encoded  \
# Account             ...
# 10491               ...                               39                   23
# 17475               ...                               39                   23
# 19901               ...                               39                   23
# 309745              ...                               39                   23
# 652229              ...                               38                   23
# 121439              ...                               22                   23
# 9948                ...                               36                   40
# 13973               ...                               36                   40
# 18052               ...                               36                   40
# 18535               ...                               37                   23
#
#          Salesperson_encoded  AH_Program_encoded  OTC_Front-end_Size_encoded  \
# Account
# 10491                      1                   4                           1
# 17475                      1                   0                           3
# 19901                      1                   0                           4
# 309745                     1                   0                           1
# 652229                     1                   0                           0
# 121439                     2                   0                           4
# 9948                       2                   0                           1
# 13973                      2                   0                           6
# 18052                      2                   0                           0
# 18535                      2                   0                           1
#
#          MRA_Program_Type_-_Active_AH_encoded  Msa_Dma_encoded  \
# Account
# 10491                                       7              183
# 17475                                       3              190
# 19901                                       2              183
# 309745                                      8              183
# 652229                                      8              183
# 121439                                      2               51
# 9948                                        3               48
# 13973                                       8                6
# 18052                                       8                6
# 18535                                       8               48
#
#          Signage_Program_encoded  3rd_Party_Vendor_encoded  \
# Account
# 10491                          0                        18
# 17475                          0                        18
# 19901                          0                        18
# 309745                         3                        18
# 652229                         0                        18
# 121439                         1                        18
# 9948                           1                        18
# 13973                          2                        18
# 18052                          0                        18
# 18535                          1                        18
#
#          Hospital_Associated_encoded
# Account
# 10491                             15
# 17475                             15
# 19901                             15
# 309745                            15
# 652229                            15
# 121439                            10
# 9948                              15
# 13973                             15
# 18052                             15
# 18535                             15
#
# [10 rows x 61 columns]

# %%
for i, col in enumerate(X.columns):            # check VIF
    print('VIF {}: {}'.format(col,variance_inflation_factor(X.values,i)))
# Out:
# VIF Zip: 17.626985413625853
# VIF Hm_Start_Dt: 166787.79216119126
# VIF Channel_Type_Cd: 861.09592836073
# VIF Auto_Ship_Ind: 2.146000403097909
# VIF Interior_Decor_Signage_Available_Funds: 4.942077816604081
# VIF LMS_Enrolled: 7.997987022380679
# VIF LMS_Available_Matching_Funds: 1.6579891343946211
# VIF LMS_Used_Funds_Most_Recent_3_Months: 3.4369092181080823
# VIF LMS_Used_Funds_Previous_3_Months: 3.4036959320820066
# VIF Open_Smart: 1.3565776640250051
# VIF PIP_Program: 2.203341013424788
# VIF KYN_Training: 15581.257511349677
# VIF PQS_Program: 10.848809544909837
# VIF Last_EQuIPP_Login: 20634.132387700727
# VIF PQS_Enrolled_Date: 158661.25631730212
# VIF SCS_Program: 4.1777450040510535
# VIF Spar_Coverage_Ind: 4.826557193587186
# VIF Specialty_Solutions: 1.1312425850305632
# VIF Vaccine_Items: 2.7339459579115784
# VIF Vaccine_Starter: 1.0728232092588774
# VIF Vaccine_Items_Count: 3.0667708066557813
# VIF Vaccine_Items_Sls_Amt: 2.27507498587236
# VIF YPO: 1.6442642908483625
# VIF Tot_Sls_Amt: 276574423641.75366
# VIF Brand_Rx_Sls_Amt: 214784415651.01566
# VIF Gnrc_Rx_Sls_Amt: 101907106.88470396
# VIF Os_Gnrc_Rx_Sls_Amt: 5281439469.569797
# VIF Otc_Sls_Amt: 368097060.9953616
# VIF 340B_Active: 107.80919933200519
# VIF Profitability: 3.698454701039455
# VIF Annual_Dispense_Fee_Total: 7.580983036274163
# VIF Macro_PID: 2.9064047970818234
# VIF Script_Count: 7.310791042060586
# VIF Capture_Rate: 9.145815996731914
# VIF Specialty_Spend: 22.984345925571866
# VIF Specialty_Product_Purchases: 24.97074131025292
# VIF Generic: 4.338236713753943
# VIF Brand: 8.693237413528742
# VIF Generic_Ratio: 10.088129179809068
# VIF DLC_Program_encoded: 5.323600333643333
# VIF FEM_Program_encoded: 4.160960976925259
# VIF HM_Circular_Program_encoded: 4.410281466128512
# VIF Internal_Decor: 3.3143012613937257
# VIF PQS_Enrolled_encoded: 9.385947087801796
# VIF ST_encoded: 3.94589422061084
# VIF Pog_Code_Name_encoded: 5.084045254254067
# VIF DC_Name_encoded: 5.0392289187990515
# VIF Bus_Type_Desc_encoded: 1.1253989279777206
# VIF Region_encoded: 5.055039495845124
# VIF PSAO_Expanded_encoded: 3.3495988740349056
# VIF Buying_Group_encoded: 15.075209581975164
# VIF Chain_Name_encoded: 18.749592296656097
# VIF Region_Name_encoded: 17.051230244297912
# VIF Salesperson_encoded: 4.181981979124673
# VIF AH_Program_encoded: 3.742731114199349
# VIF OTC_Front-end_Size_encoded: 5.868737185248401
# VIF MRA_Program_Type_-_Active_AH_encoded: 9.517176506180798
# VIF Msa_Dma_encoded: 10.839771235082857
# VIF Signage_Program_encoded: 3.5081310858958332
# VIF 3rd_Party_Vendor_encoded: 41.714744526162896
# VIF Hospital_Associated_encoded: 15.715316610389698

# %%
X1 = X.drop(df_clean[date_cols], axis=1)       # removing highly correlated date columns (b/c converted to numeric)
for i, col in enumerate(X1.columns):            # check VIF
    print('VIF {}: {}'.format(col,variance_inflation_factor(X1.values,i)))
# Out:
# VIF Zip: 17.605049977597528
# VIF Channel_Type_Cd: 180.74268976755818
# VIF Auto_Ship_Ind: 2.1431289568408256
# VIF Interior_Decor_Signage_Available_Funds: 4.860019524719944
# VIF LMS_Enrolled: 7.919643091999739
# VIF LMS_Available_Matching_Funds: 1.6410297847545097
# VIF LMS_Used_Funds_Most_Recent_3_Months: 3.4290422041552273
# VIF LMS_Used_Funds_Previous_3_Months: 3.400218149356471
# VIF Open_Smart: 1.3304060281793773
# VIF PIP_Program: 2.197827495676608
# VIF PQS_Program: 8.43104622272699
# VIF SCS_Program: 4.149776127875367
# VIF Spar_Coverage_Ind: 4.770822085858102
# VIF Specialty_Solutions: 1.130739989143978
# VIF Vaccine_Items: 2.7265039392678494
# VIF Vaccine_Starter: 1.0701675359864176
# VIF Vaccine_Items_Count: 3.0636333680915984
# VIF Vaccine_Items_Sls_Amt: 2.270733087298727
# VIF YPO: 1.6417811641608955
# VIF Tot_Sls_Amt: 276438610770.67773
# VIF Brand_Rx_Sls_Amt: 214676913381.34262
# VIF Gnrc_Rx_Sls_Amt: 101858012.74042861
# VIF Os_Gnrc_Rx_Sls_Amt: 5278892022.609001
# VIF Otc_Sls_Amt: 367919638.95987093
# VIF 340B_Active: 96.2035747135819
# VIF Profitability: 3.6959055349478067
# VIF Annual_Dispense_Fee_Total: 7.574271782756075
# VIF Macro_PID: 2.903460299570572
# VIF Script_Count: 7.302721798487088
# VIF Capture_Rate: 9.142839518213785
# VIF Specialty_Spend: 22.801764370770716
# VIF Specialty_Product_Purchases: 24.795413009565202
# VIF Generic: 4.336805639706294
# VIF Brand: 8.685704028657677
# VIF Generic_Ratio: 10.076473805310219
# VIF DLC_Program_encoded: 5.232710639702908
# VIF FEM_Program_encoded: 4.126948996863716
# VIF HM_Circular_Program_encoded: 4.4097410616946515
# VIF Internal_Decor: 3.162448085518671
# VIF PQS_Enrolled_encoded: 2.147019921900929
# VIF ST_encoded: 3.933429867588571
# VIF Pog_Code_Name_encoded: 5.040748004135989
# VIF DC_Name_encoded: 5.008766057474175
# VIF Bus_Type_Desc_encoded: 1.095361320149974
# VIF Region_encoded: 5.041148257882717
# VIF PSAO_Expanded_encoded: 3.327100960435851
# VIF Buying_Group_encoded: 15.041117064799414
# VIF Chain_Name_encoded: 18.69492185195456
# VIF Region_Name_encoded: 16.096281098117238
# VIF Salesperson_encoded: 4.172947796040173
# VIF AH_Program_encoded: 3.7156174425782047
# VIF OTC_Front-end_Size_encoded: 5.862825332817793
# VIF MRA_Program_Type_-_Active_AH_encoded: 9.362266953819635
# VIF Msa_Dma_encoded: 10.830618478906283
# VIF Signage_Program_encoded: 3.472293728533837
# VIF 3rd_Party_Vendor_encoded: 41.480961341753755
# VIF Hospital_Associated_encoded: 15.676110358699479

# %%
X2 = X1.drop(['Brand_Rx_Sls_Amt','Gnrc_Rx_Sls_Amt','Os_Gnrc_Rx_Sls_Amt','Otc_Sls_Amt'], axis=1)    # remove $ sub-cats

# %%
for i, col in enumerate(X2.columns):
    print('VIF {}: {}'.format(col,variance_inflation_factor(X2.values,i)))
# Out:
# VIF Zip: 17.499720236425627
# VIF Channel_Type_Cd: 178.60134539973365
# VIF Auto_Ship_Ind: 2.125540980730421
# VIF Interior_Decor_Signage_Available_Funds: 4.855752707559133
# VIF LMS_Enrolled: 7.892263638835095
# VIF LMS_Available_Matching_Funds: 1.6400277369935408
# VIF LMS_Used_Funds_Most_Recent_3_Months: 3.4212271110703525
# VIF LMS_Used_Funds_Previous_3_Months: 3.397397934478947
# VIF Open_Smart: 1.329562952190002
# VIF PIP_Program: 2.196758507380446
# VIF PQS_Program: 8.425823316817128
# VIF SCS_Program: 4.146574773147945
# VIF Spar_Coverage_Ind: 4.760256460843783
# VIF Specialty_Solutions: 1.1293134283904107
# VIF Vaccine_Items: 2.7038479965265587
# VIF Vaccine_Starter: 1.0698188300496838
# VIF Vaccine_Items_Count: 3.056872774062806
# VIF Vaccine_Items_Sls_Amt: 2.249114789383045
# VIF YPO: 1.6353573425177121
# VIF Tot_Sls_Amt: 1.6354117806178923
# VIF 340B_Active: 95.72835472204008
# VIF Profitability: 3.6904078268875145
# VIF Annual_Dispense_Fee_Total: 7.545222790140893
# VIF Macro_PID: 2.9024755109628453
# VIF Script_Count: 7.29665281924908
# VIF Capture_Rate: 9.1290663792544
# VIF Specialty_Spend: 22.795195210872873
# VIF Specialty_Product_Purchases: 24.789657239291383
# VIF Generic: 4.336559399468182
# VIF Brand: 8.684482431778058
# VIF Generic_Ratio: 10.073341411686563
# VIF DLC_Program_encoded: 5.228914566825153
# VIF FEM_Program_encoded: 4.122273209794145
# VIF HM_Circular_Program_encoded: 4.403812023642453
# VIF Internal_Decor: 3.131719046731606
# VIF PQS_Enrolled_encoded: 2.1446509997699237
# VIF ST_encoded: 3.924470640211565
# VIF Pog_Code_Name_encoded: 5.024550310548111
# VIF DC_Name_encoded: 4.989286862229686
# VIF Bus_Type_Desc_encoded: 1.0912968775179974
# VIF Region_encoded: 5.0141651018922815
# VIF PSAO_Expanded_encoded: 3.3083689208127236
# VIF Buying_Group_encoded: 14.872273953068985
# VIF Chain_Name_encoded: 18.53160323140058
# VIF Region_Name_encoded: 16.070082044086917
# VIF Salesperson_encoded: 4.170385218858284
# VIF AH_Program_encoded: 3.6953793562468347
# VIF OTC_Front-end_Size_encoded: 5.858710540961129
# VIF MRA_Program_Type_-_Active_AH_encoded: 9.191421765111073
# VIF Msa_Dma_encoded: 10.767182527126334
# VIF Signage_Program_encoded: 3.4628067131405955
# VIF 3rd_Party_Vendor_encoded: 41.38605085895769
# VIF Hospital_Associated_encoded: 15.63552034854417

# %%
X3 = X2.drop(['Channel_Type_Cd', '340B_Active','Zip','Region_Name_encoded','Buying_Group_encoded','3rd_Party_Vendor_encoded'], axis=1)    # remove high VIF value

# %%
MH_only_cols = ['Profitability',
       'Annual_Dispense_Fee_Total', 'Macro_PID', 'Script_Count',
       'Capture_Rate', 'Specialty_Spend', 'Specialty_Product_Purchases',
       'Generic', 'Brand', 'Generic_Ratio']
X3 = X3.drop(df_clean[MH_only_cols], axis=1)

# %%
for i, col in enumerate(X3.columns):
    print('VIF {}: {}'.format(col,variance_inflation_factor(X3.values,i)))
# Out:
# VIF Auto_Ship_Ind: 2.052200894950357
# VIF Interior_Decor_Signage_Available_Funds: 4.660827427512013
# VIF LMS_Enrolled: 7.088363837713384
# VIF LMS_Available_Matching_Funds: 1.59470373598972
# VIF LMS_Used_Funds_Most_Recent_3_Months: 3.4065931564378054
# VIF LMS_Used_Funds_Previous_3_Months: 3.3776776803037087
# VIF Open_Smart: 1.2651425666042655
# VIF PIP_Program: 2.184338552262139
# VIF PQS_Program: 7.9368326598802525
# VIF SCS_Program: 4.057779920500175
# VIF Spar_Coverage_Ind: 4.282448228615
# VIF Specialty_Solutions: 1.1234214043629231
# VIF Vaccine_Items: 2.681583676965503
# VIF Vaccine_Starter: 1.066193020249581
# VIF Vaccine_Items_Count: 3.051740296485936
# VIF Vaccine_Items_Sls_Amt: 2.2362709807729657
# VIF YPO: 1.6165183377243193
# VIF Tot_Sls_Amt: 1.6065453258223077
# VIF DLC_Program_encoded: 4.980035868145702
# VIF FEM_Program_encoded: 3.9218684876129664
# VIF HM_Circular_Program_encoded: 4.272935011493843
# VIF Internal_Decor: 2.8688959159696323
# VIF PQS_Enrolled_encoded: 2.067641857158895
# VIF ST_encoded: 3.4546073216505455
# VIF Pog_Code_Name_encoded: 4.68810680310684
# VIF DC_Name_encoded: 4.700039024114625
# VIF Bus_Type_Desc_encoded: 1.0772228659038152
# VIF Region_encoded: 4.8080494649366345
# VIF PSAO_Expanded_encoded: 3.173257903970573
# VIF Chain_Name_encoded: 3.591984583393864
# VIF Salesperson_encoded: 3.922741069941778
# VIF AH_Program_encoded: 3.534009214313584
# VIF OTC_Front-end_Size_encoded: 5.781540601770836
# VIF MRA_Program_Type_-_Active_AH_encoded: 7.880654921997656
# VIF Msa_Dma_encoded: 4.885301607736613
# VIF Signage_Program_encoded: 3.3587253183622487
# VIF Hospital_Associated_encoded: 7.123437538136087

# %%
# need to do test_train_split

X_train, X_test, y_train, y_test = train_test_split(X3, y, test_size=0.33, random_state=42)

# %%
from sklearn.metrics import recall_score, average_precision_score

# %%
# random forest

rf = RandomForestClassifier()
rf.fit(X_train, y_train)
rf.feature_importances_
pred_rf = rf.predict(X_test) 
rf_score_r2 = np.mean(cross_val_score(rf, X_train, y_train, scoring='r2', cv=5))
rf_score_recall = recall_score(y_test, pred_rf, average='weighted')
rf_score_avgprecision = average_precision_score(y_test, pred_rf)
print(rf_score_r2, rf_score_recall, rf_score_avgprecision)
# Out:
# 0.291487662175 0.970625 0.248448275862

# %%
feature_imp = pd.DataFrame({'Portion of Samples Affected' : rf.feature_importances_}, index=X3.columns)
print(feature_imp)
# Out:
#                                         Portion of Samples Affected
# Auto_Ship_Ind                                              0.010925
# Interior_Decor_Signage_Available_Funds                     0.028809
# LMS_Enrolled                                               0.006030
# LMS_Available_Matching_Funds                               0.044850
# LMS_Used_Funds_Most_Recent_3_Months                        0.002833
# LMS_Used_Funds_Previous_3_Months                           0.005038
# Open_Smart                                                 0.001660
# PIP_Program                                                0.011891
# PQS_Program                                                0.002252
# SCS_Program                                                0.011452
# Spar_Coverage_Ind                                          0.008817
# Specialty_Solutions                                        0.000000
# Vaccine_Items                                              0.010923
# Vaccine_Starter                                            0.005125
# Vaccine_Items_Count                                        0.019086
# Vaccine_Items_Sls_Amt                                      0.020008
# YPO                                                        0.009540
# Tot_Sls_Amt                                                0.043514
# DLC_Program_encoded                                        0.014219
# FEM_Program_encoded                                        0.010791
# HM_Circular_Program_encoded                                0.014953
# Internal_Decor                                             0.006011
# PQS_Enrolled_encoded                                       0.002138
# ST_encoded                                                 0.049626
# Pog_Code_Name_encoded                                      0.010257
# DC_Name_encoded                                            0.050984
# Bus_Type_Desc_encoded                                      0.013792
# Region_encoded                                             0.036425
# PSAO_Expanded_encoded                                      0.004951
# Chain_Name_encoded                                         0.045005
# Salesperson_encoded                                        0.042270
# AH_Program_encoded                                         0.006240
# OTC_Front-end_Size_encoded                                 0.024785
# MRA_Program_Type_-_Active_AH_encoded                       0.032574
# Msa_Dma_encoded                                            0.059732
# Signage_Program_encoded                                    0.015282
# Hospital_Associated_encoded                                0.317213

# %%
# decision tree

dt = DecisionTreeClassifier()
dt.fit(X_train, y_train)
dt.feature_importances_
pred_dt = dt.predict(X_test) 
dt_score_r2 = np.mean(cross_val_score(dt, X_train, y_train, scoring='r2', cv=5))
dt_score_recall = recall_score(y_test, pred_dt, average='weighted')
dt_score_avgprecision = average_precision_score(y_test, pred_dt)
print(dt_score_r2, dt_score_recall, dt_score_avgprecision)
# Out:
# 0.0372847265824 0.961875 0.271782161804

# %%
# some way to plot pred_rf against y_test
# and plot pred_dt against y_test

# %%
# don't know if logit (logistic regression) has an r2?
# trying to beat an r2 of .69

# %%
X3.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000000C838CC0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000C6B7470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000C6B2D30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000C5EB320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000C7A6BA8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000C7A6BE0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000000C71F128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000C703668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000C58B668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000C88C668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000C8B4BA8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000DC8EF98>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000000DCB7F98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000DCDDF98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000DD4C518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000DD54828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000DD8EA58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000DDB8A58>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000000DDDEF98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000E176F98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000E1974A8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000E87E438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000E8A74A8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000E8CF4A8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000000E87EF98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000E9170B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000E9400B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000E9660B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000E98E588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000E9ABB38>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000000E9D1B38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000E9FAB38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000EA28048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000EC444A8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000EC6C438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000F0A2438>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000000F0CB908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000F0D2BA8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000F117F28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000F13FF28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000F176438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000000110323C8>]], dtype=object)

# %%
###########################################
# TEST BLOCK
###########################################

X_gbc = X3
# initial run making sure it works
X_gbc_train, X_gbc_test, y_train, y_test = train_test_split(X_gbc, y, test_size=0.33, random_state=42)

model = GradientBoostingClassifier().fit(X_gbc_train, y_train)
print(model.score(X_gbc_test, y_test))

# commented out since we already have our predictor
cv = KFold(n_splits=10)
accuracy = []
for estimator in range(100, 1000, 100):
    for depth in range(1, 4):
        for sample in (0.1, 0.3, 0.5, 0.7, 0.9):
            model = GradientBoostingClassifier(n_estimators=estimator, max_depth=depth, subsample=sample)
            scores = []
            for train_i, test_i in cv.split(X_gbc):
                # Xr, yr, Xt, yt = X.loc[train_i], y.loc[train_i], X.loc[test_i], y.loc[test_i]
                Xr, yr, Xt, yt = X.loc[train_i], y.loc[train_i], X.loc[test_i], y.loc[test_i]
                model.fit(Xr, yr)
                scores.append(model.score(Xt, yt))
                accuracy = sum(scores) / len(scores)
            print('sample:', sample, 'depth:', depth, 'estimators:', estimator, 'accuracy:', sum(scores) / len(scores))
print(accuracy.max)

# best hyperparameters
# sample: 0.5 depth: 1 estimators: 100 accuracy: 0.808817204301
# model = GradientBoostingClassifier(
#     n_estimators=100, max_depth=1, subsample=0.9).fit(X, y)
# Out:
# 0.975625
# sample: 0.1 depth: 1 estimators: 100 accuracy: 0.995461361506
# sample: 0.3 depth: 1 estimators: 100 accuracy: 0.995667547073
# sample: 0.5 depth: 1 estimators: 100 accuracy: 0.996905086479
# sample: 0.7 depth: 1 estimators: 100 accuracy: 0.997317457613
# sample: 0.9 depth: 1 estimators: 100 accuracy: 0.998350515464
# sample: 0.1 depth: 2 estimators: 100 accuracy: 0.995874584647
# sample: 0.3 depth: 2 estimators: 100 accuracy: 0.998350515464
# sample: 0.5 depth: 2 estimators: 100 accuracy: 0.998350515464
# sample: 0.7 depth: 2 estimators: 100 accuracy: 0.998350515464
# sample: 0.9 depth: 2 estimators: 100 accuracy: 0.997937718327
# sample: 0.1 depth: 3 estimators: 100 accuracy: 0.996080344211
# sample: 0.3 depth: 3 estimators: 100 accuracy: 0.998350515464
# sample: 0.5 depth: 3 estimators: 100 accuracy: 0.998350515464
# sample: 0.7 depth: 3 estimators: 100 accuracy: 0.998350515464
# sample: 0.9 depth: 3 estimators: 100 accuracy: 0.998144329897
# sample: 0.1 depth: 1 estimators: 200 accuracy: 0.995874158644
# sample: 0.3 depth: 1 estimators: 200 accuracy: 0.997318309619
# sample: 0.5 depth: 1 estimators: 200 accuracy: 0.998350515464
# sample: 0.7 depth: 1 estimators: 200 accuracy: 0.998350515464
# sample: 0.9 depth: 1 estimators: 200 accuracy: 0.998350515464
# sample: 0.1 depth: 2 estimators: 200 accuracy: 0.997112124052
# sample: 0.3 depth: 2 estimators: 200 accuracy: 0.998350515464
# sample: 0.5 depth: 2 estimators: 200 accuracy: 0.998350515464
# sample: 0.7 depth: 2 estimators: 200 accuracy: 0.998350515464
# sample: 0.9 depth: 2 estimators: 200 accuracy: 0.998144329897
# sample: 0.1 depth: 3 estimators: 200 accuracy: 0.99793814433
# sample: 0.3 depth: 3 estimators: 200 accuracy: 0.998350515464
# sample: 0.5 depth: 3 estimators: 200 accuracy: 0.998144329897
# sample: 0.7 depth: 3 estimators: 200 accuracy: 0.998350515464
# sample: 0.9 depth: 3 estimators: 200 accuracy: 0.998144329897
# sample: 0.1 depth: 1 estimators: 300 accuracy: 0.996493141348
# sample: 0.3 depth: 1 estimators: 300 accuracy: 0.998144329897
# sample: 0.5 depth: 1 estimators: 300 accuracy: 0.998350515464
# sample: 0.7 depth: 1 estimators: 300 accuracy: 0.998144329897
# sample: 0.9 depth: 1 estimators: 300 accuracy: 0.997937718327
# sample: 0.1 depth: 2 estimators: 300 accuracy: 0.998350515464
# sample: 0.3 depth: 2 estimators: 300 accuracy: 0.998350515464
# sample: 0.5 depth: 2 estimators: 300 accuracy: 0.998350515464
# sample: 0.7 depth: 2 estimators: 300 accuracy: 0.998144329897
# sample: 0.9 depth: 2 estimators: 300 accuracy: 0.997937718327
# sample: 0.1 depth: 3 estimators: 300 accuracy: 0.997731958763
# sample: 0.3 depth: 3 estimators: 300 accuracy: 0.998350515464
# sample: 0.5 depth: 3 estimators: 300 accuracy: 0.998350515464
# sample: 0.7 depth: 3 estimators: 300 accuracy: 0.998350515464
# sample: 0.9 depth: 3 estimators: 300 accuracy: 0.998144329897
# sample: 0.1 depth: 1 estimators: 400 accuracy: 0.997112124052
# sample: 0.3 depth: 1 estimators: 400 accuracy: 0.998144329897
# sample: 0.5 depth: 1 estimators: 400 accuracy: 0.998143903894
# sample: 0.7 depth: 1 estimators: 400 accuracy: 0.997937718327
# sample: 0.9 depth: 1 estimators: 400 accuracy: 0.997524495186
# sample: 0.1 depth: 2 estimators: 400 accuracy: 0.99793814433
# sample: 0.3 depth: 2 estimators: 400 accuracy: 0.998350515464
# sample: 0.5 depth: 2 estimators: 400 accuracy: 0.998350515464
# sample: 0.7 depth: 2 estimators: 400 accuracy: 0.997937718327
# sample: 0.9 depth: 2 estimators: 400 accuracy: 0.99773153276
# sample: 0.1 depth: 3 estimators: 400 accuracy: 0.997731958763
# sample: 0.3 depth: 3 estimators: 400 accuracy: 0.998350515464
# sample: 0.5 depth: 3 estimators: 400 accuracy: 0.998350515464
# sample: 0.7 depth: 3 estimators: 400 accuracy: 0.998350515464
# sample: 0.9 depth: 3 estimators: 400 accuracy: 0.998144329897
# sample: 0.1 depth: 1 estimators: 500 accuracy: 0.998143903894
# sample: 0.3 depth: 1 estimators: 500 accuracy: 0.998144329897
# sample: 0.5 depth: 1 estimators: 500 accuracy: 0.998143903894
# sample: 0.7 depth: 1 estimators: 500 accuracy: 0.997731106756
# sample: 0.9 depth: 1 estimators: 500 accuracy: 0.997318309619
# sample: 0.1 depth: 2 estimators: 500 accuracy: 0.998143903894
# sample: 0.3 depth: 2 estimators: 500 accuracy: 0.998350515464
# sample: 0.5 depth: 2 estimators: 500 accuracy: 0.998350515464
# sample: 0.7 depth: 2 estimators: 500 accuracy: 0.998143903894
# sample: 0.9 depth: 2 estimators: 500 accuracy: 0.997937718327
# sample: 0.1 depth: 3 estimators: 500 accuracy: 0.99793814433
# sample: 0.3 depth: 3 estimators: 500 accuracy: 0.998350515464
# sample: 0.5 depth: 3 estimators: 500 accuracy: 0.998350515464
# sample: 0.7 depth: 3 estimators: 500 accuracy: 0.998350515464
# sample: 0.9 depth: 3 estimators: 500 accuracy: 0.998144329897
# sample: 0.1 depth: 1 estimators: 600 accuracy: 0.997524495186
# sample: 0.3 depth: 1 estimators: 600 accuracy: 0.998143903894
# sample: 0.5 depth: 1 estimators: 600 accuracy: 0.998143903894
# sample: 0.7 depth: 1 estimators: 600 accuracy: 0.997524921189
# sample: 0.9 depth: 1 estimators: 600 accuracy: 0.997318309619
# sample: 0.1 depth: 2 estimators: 600 accuracy: 0.99793814433
# sample: 0.3 depth: 2 estimators: 600 accuracy: 0.998350515464
# sample: 0.5 depth: 2 estimators: 600 accuracy: 0.998350515464
# sample: 0.7 depth: 2 estimators: 600 accuracy: 0.998144329897
# sample: 0.9 depth: 2 estimators: 600 accuracy: 0.997937718327
# sample: 0.1 depth: 3 estimators: 600 accuracy: 0.99793814433
# sample: 0.3 depth: 3 estimators: 600 accuracy: 0.998144329897
# sample: 0.5 depth: 3 estimators: 600 accuracy: 0.998350515464
# sample: 0.7 depth: 3 estimators: 600 accuracy: 0.998350515464
# sample: 0.9 depth: 3 estimators: 600 accuracy: 0.998144329897
# sample: 0.1 depth: 1 estimators: 700 accuracy: 0.998143903894
# sample: 0.3 depth: 1 estimators: 700 accuracy: 0.998143903894
# sample: 0.5 depth: 1 estimators: 700 accuracy: 0.997937292323
# sample: 0.7 depth: 1 estimators: 700 accuracy: 0.997731106756
# sample: 0.9 depth: 1 estimators: 700 accuracy: 0.997524921189
# sample: 0.1 depth: 2 estimators: 700 accuracy: 0.998350515464
# sample: 0.3 depth: 2 estimators: 700 accuracy: 0.99793814433
# sample: 0.5 depth: 2 estimators: 700 accuracy: 0.998350515464
# sample: 0.7 depth: 2 estimators: 700 accuracy: 0.998144329897
# sample: 0.9 depth: 2 estimators: 700 accuracy: 0.997937718327
# sample: 0.1 depth: 3 estimators: 700 accuracy: 0.995251767913
# sample: 0.3 depth: 3 estimators: 700 accuracy: 0.998350515464
# sample: 0.5 depth: 3 estimators: 700 accuracy: 0.998350515464
# sample: 0.7 depth: 3 estimators: 700 accuracy: 0.998350515464
# sample: 0.9 depth: 3 estimators: 700 accuracy: 0.998144329897
# sample: 0.1 depth: 1 estimators: 800 accuracy: 0.99793814433
# sample: 0.3 depth: 1 estimators: 800 accuracy: 0.997937292323
# sample: 0.5 depth: 1 estimators: 800 accuracy: 0.997937292323
# sample: 0.7 depth: 1 estimators: 800 accuracy: 0.997318735622
# sample: 0.9 depth: 1 estimators: 800 accuracy: 0.997524921189
# sample: 0.1 depth: 2 estimators: 800 accuracy: 0.997937718327
# sample: 0.3 depth: 2 estimators: 800 accuracy: 0.998144329897
# sample: 0.5 depth: 2 estimators: 800 accuracy: 0.998350515464
# sample: 0.7 depth: 2 estimators: 800 accuracy: 0.998350515464
# sample: 0.9 depth: 2 estimators: 800 accuracy: 0.997937718327
# sample: 0.1 depth: 3 estimators: 800 accuracy: 0.99773153276
# sample: 0.3 depth: 3 estimators: 800 accuracy: 0.998144329897
# sample: 0.5 depth: 3 estimators: 800 accuracy: 0.998350515464
# sample: 0.7 depth: 3 estimators: 800 accuracy: 0.998350515464
# sample: 0.9 depth: 3 estimators: 800 accuracy: 0.998144329897
# sample: 0.1 depth: 1 estimators: 900 accuracy: 0.998350515464
# sample: 0.3 depth: 1 estimators: 900 accuracy: 0.998143903894
# sample: 0.5 depth: 1 estimators: 900 accuracy: 0.997937292323
# sample: 0.7 depth: 1 estimators: 900 accuracy: 0.997731106756
# sample: 0.9 depth: 1 estimators: 900 accuracy: 0.997318309619
# sample: 0.1 depth: 2 estimators: 900 accuracy: 0.998350515464
# sample: 0.3 depth: 2 estimators: 900 accuracy: 0.99793814433
# sample: 0.5 depth: 2 estimators: 900 accuracy: 0.998350515464
# sample: 0.7 depth: 2 estimators: 900 accuracy: 0.998350515464
# sample: 0.9 depth: 2 estimators: 900 accuracy: 0.998144329897
# sample: 0.1 depth: 3 estimators: 900 accuracy: 0.997525347193
# sample: 0.3 depth: 3 estimators: 900 accuracy: 0.998144329897
# sample: 0.5 depth: 3 estimators: 900 accuracy: 0.998350515464
# sample: 0.7 depth: 3 estimators: 900 accuracy: 0.998350515464
# sample: 0.9 depth: 3 estimators: 900 accuracy: 0.998144329897
# <built-in method max of numpy.float64 object at 0x000000000C5F2300>
